# %% [markdown]
# # Laden des Datensatzes

# %%
import pandas as pd
from sklearn import datasets
import matplotlib.pyplot as plt

iris = datasets.load_iris()
iris_df = pd.DataFrame(iris.data)
iris_df['class']=iris.target_names[iris.target ]
iris_df.columns=['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']

# %% [markdown]
# # Überblick

# %%
iris_df.info()
#iris_df.shape
#iris_df.head(5)
#iris_df.dtypes
#print( iris_df.describe() )
print (type( iris_df.iloc[0,4]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   sepal_len  150 non-null    float64
#  1   sepal_wid  150 non-null    float64
#  2   petal_len  150 non-null    float64
#  3   petal_wid  150 non-null    float64
#  4   class      150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB
# <class 'str'>

# %% [markdown]
# ## Unique Values

# %%
import pandas as pd

iris_df.nunique()
# Out:
# sepal_len    35
# sepal_wid    23
# petal_len    43
# petal_wid    22
# class         3
# dtype: int64

# %% [markdown]
# # Single Numerical Feature

# %% [markdown]
# ## Swarmplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Iris Swarmplot - petal-width")
ax = sns.swarmplot(data = iris_df,  x = "petal_wid")

# %% [markdown]
# ## Histogramm

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
sns.histplot(data = iris_df, 
             x ="petal_wid", 
             bins=10,  # try bins="auto" und bins=10
             kde = False)
# Out:
# <AxesSubplot:xlabel='petal_wid', ylabel='Count'>

# %% [markdown]
# ## Violinplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Iris Swarmplot - petal-width")
ax = sns.violinplot(data = iris_df,  x = "petal_wid", inner="quartiles")

# %% [markdown]
# ## Boxplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Iris Swarmplot - petal-width")
ax = sns.boxplot(data = iris_df,  x = "petal_wid")

# %% [markdown]
# # Single Feature vs. Category

# %% [markdown]
# ## Swarm

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Iris Swarmplot - petal-width")
ax = sns.swarmplot(data = iris_df,  x = "petal_wid", y="class")
# Out:
# C:\Python39\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 24.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Violin

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Iris Swarmplot - petal-width")
ax = sns.violinplot(data = iris_df,  x = "petal_wid", y = "class", inner="quartiles")

# %% [markdown]
# # Relation-Plots

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
sns.set_context("notebook", font_scale=1.2)
sns.relplot(data=iris_df, x="petal_len", y="sepal_wid", hue = "class", height=7, s = 50) # try style="class"

# %% [markdown]
# # Pairplots

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

sns.set()
sns.set_context("notebook", font_scale=1.3)

sns.pairplot(iris_df[['sepal_len', 'sepal_wid', 'petal_len', 'petal_wid', 'class']],
             hue="class", diag_kind="kde")
