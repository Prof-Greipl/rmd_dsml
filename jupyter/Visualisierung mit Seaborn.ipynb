# %% [markdown]
# ## Swarmplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.tight_layout(pad=1.08, h_pad=None, w_pad=None, rect=None)

sns.set_theme()

fig, ax = plt.subplots( figsize=(9,6))
ax.set_title("Swarmplot")

data = np.random.uniform(1,100, size=600)
sns.swarmplot(x = data)
# Out:
# <AxesSubplot:title={'center':'Swarmplot'}>

# %% [markdown]
# ## Percentile

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

x = np.arange(1,101)

percentiles = np.percentile( x, [0,25,50,75,100])
print( "Pericentile         : ", percentiles)

#x = np.concatenate( (x, [152] ))
#percentiles = np.percentile( x, [0,25,50,75,100])
#print( "Pericentile         : ", percentiles)
# Out:
# Pericentile         :  [  1.    25.75  50.5   75.25 100.  ]

# %% [markdown]
# ## Boxplots

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

data = np.arange(1,101)
data = np.concatenate( (data, [151]) )

percentiles = np.percentile( data , [0,25,50,75,100])
IQR = (percentiles[3] -  percentiles[1])
print( "Pericentile         : ", percentiles)
print( "IQR                 : ", IQR)
print( "Upper Outlier Limit : ", percentiles[3] + 1.5*IQR)
sns.boxplot(x = data)

# %% [markdown]
# ### Relplot

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
data = np.array([
         [ 1, 2,"C"],
         [ 2, 2,"C"],
         [ 3, 2,"A"],
         [ 4, 3,"A"],
         [ 5, 4,"B"],
         [ 6, 5,"A"],
         [ 7, 6,"A"],
         [ 8, 7,"C"],
         [ 9, 7,"C"],
         [10, 7,"C"]])
x_data = data[:,0]
y_data = data[:,1]
type =  data[:,2]

sns.relplot(x=x_data, y=y_data, hue=type)
